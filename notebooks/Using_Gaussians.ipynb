# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import gaussians

# %%
data = gaussians.sim_gauss_data(loc=5, scale=3)

# %%
gaussians.plot_data_and_generating_distrib(data, loc=5, scale=3, size=250, bins=20, fit=True, filepath='../figures/gaussian_2.png')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-2a931eb544c2> in <module>
# ----> 1 gaussians.plot_data_and_generating_distrib(data, loc=5, scale=3, size=250, bins=20, fit=True, filepath='../figures/gaussian_2.png')
#
# ~/Lab9/src/gaussians.py in plot_data_and_generating_distrib(data, loc, scale, size, bins, fit, filepath)
#      50     plt.legend()
#      51     if filepath:
# ---> 52         assert(os.path.exists(filepath)), "Path does not exist!"
#      53         plt.savefig(filepath)
#
# AssertionError: Path does not exist!
