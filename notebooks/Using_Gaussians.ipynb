# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../src")
import gaussians

# %%
data = gaussians.sim_gauss_data(loc=5, scale=3)

# %%
gaussians.plot_data_and_generating_distrib(data, loc=5, scale=3, size=250, 
                                           bins=20, fit=True, filepath='../figs/gaussian_2.png')
